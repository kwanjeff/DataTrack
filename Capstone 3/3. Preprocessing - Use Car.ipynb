# %% [markdown]
# Task numbering
# 1 - data masaaging and showing data
#
# 2 - correlation testing and dropping correlated data
#
# 3 - convert to dummy
#
# 4 - Train data/ fit data / scale
#
#
# 5 - export scaled and fit data

# %%
#Task 1.0  import libraries 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from  sklearn import preprocessing

# %%
#Task 1.1  import csv file
UsedVehicle=pd.read_csv(r'.\Data\UsedCarData\clean_vehicles.csv')

# %%
#Task 1.2  

UsedVehicle.head(10)
# Out:
#            id                                                url  region  \
# 0  7316814884  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 1  7316814758  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 2  7316814989  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 3  7316743432  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 4  7316356412  https://auburn.craigslist.org/cto/d/auburn-uni...  auburn
# 5  7316343444  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 6  7316304717  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 7  7316285779  https://auburn.craigslist.org/cto/d/auburn-201...  auburn
# 8  7316257769  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 9  7316133914  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
#
#                       region_url  price    year manufacturer  \
# 0  https://auburn.craigslist.org  33590  2014.0          gmc
# 1  https://auburn.craigslist.org  22590  2010.0    chevrolet
# 2  https://auburn.craigslist.org  39590  2020.0    chevrolet
# 3  https://auburn.craigslist.org  30990  2017.0       toyota
# 4  https://auburn.craigslist.org  15000  2013.0         ford
# 5  https://auburn.craigslist.org  27990  2012.0          gmc
# 6  https://auburn.craigslist.org  34590  2016.0    chevrolet
# 7  https://auburn.craigslist.org  35000  2019.0       toyota
# 8  https://auburn.craigslist.org  29990  2016.0    chevrolet
# 9  https://auburn.craigslist.org  38590  2011.0    chevrolet
#
#                          model  condition    cylinders  ...    drive  \
# 0     sierra 1500 crew cab slt       good  8 cylinders  ...  unknown
# 1               silverado 1500       good  8 cylinders  ...  unknown
# 2          silverado 1500 crew       good  8 cylinders  ...  unknown
# 3         tundra double cab sr       good  8 cylinders  ...  unknown
# 4                    f-150 xlt  excellent  6 cylinders  ...      rwd
# 5  sierra 2500 hd extended cab       good  8 cylinders  ...      4wd
# 6        silverado 1500 double       good  6 cylinders  ...      4wd
# 7                       tacoma  excellent  6 cylinders  ...      4wd
# 8        colorado extended cab       good  6 cylinders  ...      4wd
# 9         corvette grand sport       good  8 cylinders  ...      rwd
#
#         size    type paint_color  \
# 0    unknown  pickup       white
# 1    unknown  pickup        blue
# 2    unknown  pickup         red
# 3    unknown  pickup         red
# 4  full-size   truck       black
# 5    unknown  pickup       black
# 6    unknown  pickup      silver
# 7    unknown   truck        grey
# 8    unknown  pickup         red
# 9    unknown   other         red
#
#                                            image_url  \
# 0  https://images.craigslist.org/00R0R_lwWjXSEWNa...
# 1  https://images.craigslist.org/00R0R_lwWjXSEWNa...
# 2  https://images.craigslist.org/01212_jjirIWa0y0...
# 3  https://images.craigslist.org/00x0x_1y9kIOzGCF...
# 4  https://images.craigslist.org/00404_l4loxHvdQe...
# 5  https://images.craigslist.org/00V0V_ftJbKrOgdi...
# 6  https://images.craigslist.org/00E0E_iKN07Sh7ou...
# 7  https://images.craigslist.org/00101_dXoZTH7iVm...
# 8  https://images.craigslist.org/00N0N_1xMPvfxRAI...
# 9  https://images.craigslist.org/00U0U_kKYnS1LWh8...
#
#                                          description state      lat  \
# 0  Carvana is the safer way to buy a car During t...    al    32.59
# 1  Carvana is the safer way to buy a car During t...    al    32.59
# 2  Carvana is the safer way to buy a car During t...    al    32.59
# 3  Carvana is the safer way to buy a car During t...    al    32.59
# 4  2013 F-150 XLT V6 4 Door. Good condition. Leve...    al   32.592
# 5  Carvana is the safer way to buy a car During t...    al    32.59
# 6  Carvana is the safer way to buy a car During t...    al    32.59
# 7  Selling my 2019 Toyota Tacoma TRD Off Road Dou...    al  32.6013
# 8  Carvana is the safer way to buy a car During t...    al    32.59
# 9  Carvana is the safer way to buy a car During t...    al    32.59
#
#          long               posting_date
# 0      -85.48  2021-05-04 12:31:18-05:00
# 1      -85.48  2021-05-04 12:31:08-05:00
# 2      -85.48  2021-05-04 12:31:25-05:00
# 3      -85.48  2021-05-04 10:41:31-05:00
# 4    -85.5189  2021-05-03 14:02:03-05:00
# 5      -85.48  2021-05-03 13:41:25-05:00
# 6      -85.48  2021-05-03 12:41:33-05:00
# 7  -85.443974  2021-05-03 12:12:59-05:00
# 8      -85.48  2021-05-03 11:31:14-05:00
# 9      -85.48  2021-05-03 07:50:35-05:00
#
# [10 rows x 25 columns]

# %%
#Task 1.3
UsedVehicle.columns
# Out:
# Index(['id', 'url', 'region', 'region_url', 'price', 'year', 'manufacturer',
#        'model', 'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'VIN', 'drive', 'size', 'type', 'paint_color',
#        'image_url', 'description', 'state', 'lat', 'long', 'posting_date'],
#       dtype='object')

# %%
#Task 1.4
# need to drop this column as id is not a measurable column
UsedVehicle.drop(UsedVehicle[['id','url','image_url']].columns,axis=1,inplace = True)

# %%
#Task 1.5

UsedVehicle.describe()
# Out:
#               price           year      odometer
# count  4.161490e+05  416149.000000  4.161490e+05
# mean   6.158955e+04    2011.365749  9.766435e+04
# std    1.108080e+07       9.140825  2.046903e+05
# min    0.000000e+00    1900.000000  0.000000e+00
# 25%    5.995000e+03    2008.000000  3.800000e+04
# 50%    1.399100e+04    2014.000000  8.568200e+04
# 75%    2.650000e+04    2017.000000  1.335030e+05
# max    3.736929e+09    2022.000000  1.000000e+07

# %%
#Task 1.6 converting values in the column in this cell to be a more managable numbers.  Using Log1p function.  
# log1p is used instead of log because there is a column AMT_ANNUITY with value of 0

num_features=['price','odometer']

for feature in num_features:
    UsedVehicle[feature]=np.log1p(UsedVehicle[feature])

# %%
#Task 1.6
UsedVehicle.describe()
# Out:
#                price           year       odometer
# count  416149.000000  416149.000000  416149.000000
# mean        8.732425    2011.365749      10.938864
# std         2.712483       9.140825       1.621054
# min         0.000000    1900.000000       0.000000
# 25%         8.698848    2008.000000      10.545368
# 50%         9.546241    2014.000000      11.358410
# 75%        10.184938    2017.000000      11.801887
# max        22.041530    2022.000000      16.118096

# %%
UsedVehicle.head()
# Out:
#    region                     region_url      price    year manufacturer  \
# 0  auburn  https://auburn.craigslist.org  10.422013  2014.0          gmc
# 1  auburn  https://auburn.craigslist.org  10.025307  2010.0    chevrolet
# 2  auburn  https://auburn.craigslist.org  10.586357  2020.0    chevrolet
# 3  auburn  https://auburn.craigslist.org  10.341452  2017.0       toyota
# 4  auburn  https://auburn.craigslist.org   9.615872  2013.0         ford
#
#                       model  condition    cylinders fuel   odometer  ...  \
# 0  sierra 1500 crew cab slt       good  8 cylinders  gas  10.966887  ...
# 1            silverado 1500       good  8 cylinders  gas  11.173669  ...
# 2       silverado 1500 crew       good  8 cylinders  gas   9.860632  ...
# 3      tundra double cab sr       good  8 cylinders  gas  10.624371  ...
# 4                 f-150 xlt  excellent  6 cylinders  gas  11.759793  ...
#
#                  VIN    drive       size    type paint_color  \
# 0  3GTP1VEC4EG551563  unknown    unknown  pickup       white
# 1  1GCSCSE06AZ123805  unknown    unknown  pickup        blue
# 2  3GCPWCED5LG130317  unknown    unknown  pickup         red
# 3  5TFRM5F17HX120972  unknown    unknown  pickup         red
# 4              blank      rwd  full-size   truck       black
#
#                                          description state     lat      long  \
# 0  Carvana is the safer way to buy a car During t...    al   32.59    -85.48
# 1  Carvana is the safer way to buy a car During t...    al   32.59    -85.48
# 2  Carvana is the safer way to buy a car During t...    al   32.59    -85.48
# 3  Carvana is the safer way to buy a car During t...    al   32.59    -85.48
# 4  2013 F-150 XLT V6 4 Door. Good condition. Leve...    al  32.592  -85.5189
#
#                 posting_date
# 0  2021-05-04 12:31:18-05:00
# 1  2021-05-04 12:31:08-05:00
# 2  2021-05-04 12:31:25-05:00
# 3  2021-05-04 10:41:31-05:00
# 4  2021-05-03 14:02:03-05:00
#
# [5 rows x 22 columns]

# %%
# Task 2.0.0
# with the following function we can select highly correlated features
# it will identify so I can remove the first feature that is correlated with anything other feature

def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    #corr_matrix = dataset.corr()
    df= dataset.drop(columns='price')
    #df= dataset.drop(colums= 'Late_Payments')#doing this step above to 
    df_corr= df.corr()
    for i in range(len(df_corr.columns)):
        for j in range(i):
            if abs(df_corr.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = df_corr.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
#Task 2.1.1
corr_features = correlation(UsedVehicle , 0.7)#coefficent corelated if 70%, 
                                        #if i adjust threshold i can control how many feature to drop. 

len(set(corr_features))
# Out:
# 0

# %%
#Task 2.1.2
# after doing a
corr_features
# Out:
# set()

# %%
#Task 3
dummy=pd.get_dummies(UsedVehicle)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-17-c13f3d9e389e> in <module>
#       1 #Task 3
# ----> 2 dummy=pd.get_dummies(UsedVehicle)
#
# D:\ProgramData\Anaconda3\envs\springboard\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     891         for (col, pre, sep) in zip(data_to_encode.items(), prefix, prefix_sep):
#     892             # col is (column_name, column), use just column data here
# --> 893             dummy = _get_dummies_1d(
#     894                 col[1],
#     895                 prefix=pre,
#
# D:\ProgramData\Anaconda3\envs\springboard\lib\site-packages\pandas\core\reshape\reshape.py in _get_dummies_1d(data, prefix, prefix_sep, dummy_na, sparse, drop_first, dtype)
#    1007
#    1008     else:
# -> 1009         dummy_mat = np.eye(number_of_cols, dtype=dtype).take(codes, axis=0)
#    1010
#    1011         if not dummy_na:
#
# D:\ProgramData\Anaconda3\envs\springboard\lib\site-packages\numpy\lib\twodim_base.py in eye(N, M, k, dtype, order, like)
#     207     if M is None:
#     208         M = N
# --> 209     m = zeros((N, M), dtype=dtype, order=order)
#     210     if k >= M:
#     211         return m
#
# MemoryError: Unable to allocate 12.4 GiB for an array with shape (115512, 115512) and data type uint8

# %%
#Task 3.1
dummy.shape

# %%
#Task 3.2
dummy

# %%
#Task 3.3
X=dummy.drop(columns='LATE_PAYMENT')
y=dummy['LATE_PAYMENT']

X_train, X_test, y_train, y_test = train_test_split(X,y, stratify=dummy['LATE_PAYMENT'], test_size=0.25)
#remove train and split and data and will be placed into end of features

# %% [markdown]
# 1.0 Import Modules and View data to be modeled
#
# 2.0 Linear Regression
#
# 3.0 K mean clustering
#
# 4.0 Decission Tree
#
# 5.0 Time Series Aggression Analysis

# %%
#Task 1.0

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
pd.pandas.set_option('display.max_columns',None)
import warnings
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_squared_error



warnings.filterwarnings('ignore')

# %%
#Task 1.1
#In prior EDA submission, I used price column to spit the data evenly into 80/20

xTrainModel=pd.read_csv(r'.\Data\UsedCarData\X_Train_Output.csv',header=0)
xTestModel=pd.read_csv(r'.\Data\UsedCarData\X_Test_Output.csv',header=0)
yTrainModel=pd.read_csv(r'.\Data\UsedCarData\y_Train_Output.csv',header=0)
yTestModel=pd.read_csv(r'.\Data\UsedCarData\y_Test_Output.csv',header=0)
usedvehicle=pd.read_csv(r'.\Data\UsedCarData\clean_vehicles.csv', header=0 )

# %%
#Task 1.2.0
xTrainModel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97412 entries, 0 to 97411
# Columns: 104 entries, year to paint_color_yellow
# dtypes: float64(104)
# memory usage: 77.3 MB

# %%
#Task 1.2.1
xTrainModel.head()
# Out:
#        year  odometer       lat      long  manufacturer_acura  \
# 0 -0.573189  0.664925  0.418292  1.086798           -0.101225
# 1  0.482503  0.469230 -0.915502  0.314101           -0.101225
# 2  0.194587  0.354234  0.858227  0.825056           -0.101225
# 3  0.962363  0.077461  0.168420 -1.585458           -0.101225
# 4  0.386531  0.594390  0.789780  0.503675           -0.101225
#
#    manufacturer_alfa-romeo  manufacturer_aston-martin  manufacturer_audi  \
# 0                -0.019755                  -0.007165          -0.102868
# 1                -0.019755                  -0.007165          -0.102868
# 2                -0.019755                  -0.007165          -0.102868
# 3                -0.019755                  -0.007165          -0.102868
# 4                -0.019755                  -0.007165          -0.102868
#
#    manufacturer_bmw  manufacturer_buick  manufacturer_cadillac  \
# 0         -0.163293           -0.113132              -0.117609
# 1         -0.163293           -0.113132              -0.117609
# 2         -0.163293           -0.113132              -0.117609
# 3         -0.163293           -0.113132              -0.117609
# 4         -0.163293           -0.113132              -0.117609
#
#    manufacturer_chevrolet  manufacturer_chrysler  manufacturer_datsun  \
# 0               -0.415409              -0.130696             -0.01433
# 1               -0.415409              -0.130696             -0.01433
# 2               -0.415409              -0.130696             -0.01433
# 3               -0.415409              -0.130696             -0.01433
# 4               -0.415409              -0.130696             -0.01433
#
#    manufacturer_dodge  manufacturer_ferrari  manufacturer_fiat  \
# 0            -0.18831             -0.013212          -0.037115
# 1            -0.18831             -0.013212          -0.037115
# 2            -0.18831             -0.013212          -0.037115
# 3            -0.18831             -0.013212          -0.037115
# 4            -0.18831             -0.013212          -0.037115
#
#    manufacturer_ford  manufacturer_gmc  manufacturer_harley-davidson  \
# 0          -0.460172         -0.204656                     -0.017552
# 1          -0.460172          4.886244                     -0.017552
# 2           2.173103         -0.204656                     -0.017552
# 3           2.173103         -0.204656                     -0.017552
# 4           2.173103         -0.204656                     -0.017552
#
#    manufacturer_honda  manufacturer_hyundai  manufacturer_infiniti  \
# 0           -0.239705             -0.146911              -0.109493
# 1           -0.239705             -0.146911              -0.109493
# 2           -0.239705             -0.146911              -0.109493
# 3           -0.239705             -0.146911              -0.109493
# 4           -0.239705             -0.146911              -0.109493
#
#    manufacturer_jaguar  manufacturer_jeep  manufacturer_kia  \
# 0            -0.055766           -0.22781         -0.130656
# 1            -0.055766           -0.22781         -0.130656
# 2            -0.055766           -0.22781         -0.130656
# 3            -0.055766           -0.22781         -0.130656
# 4            -0.055766           -0.22781         -0.130656
#
#    manufacturer_land rover  manufacturer_lexus  manufacturer_lincoln  \
# 0                -0.009063           -0.134148             -0.097484
# 1                -0.009063           -0.134148             -0.097484
# 2                -0.009063           -0.134148             -0.097484
# 3                -0.009063           -0.134148             -0.097484
# 4                -0.009063           -0.134148             -0.097484
#
#    manufacturer_mazda  manufacturer_mercedes-benz  manufacturer_mercury  \
# 0           -0.106328                   -0.155921             -0.064132
# 1           -0.106328                   -0.155921             -0.064132
# 2           -0.106328                   -0.155921             -0.064132
# 3           -0.106328                   -0.155921             -0.064132
# 4           -0.106328                   -0.155921             -0.064132
#
#    manufacturer_mini  manufacturer_mitsubishi  manufacturer_nissan  \
# 0          -0.066587                -0.084524            -0.230687
# 1          -0.066587                -0.084524            -0.230687
# 2          -0.066587                -0.084524            -0.230687
# 3          -0.066587                -0.084524            -0.230687
# 4          -0.066587                -0.084524            -0.230687
#
#    manufacturer_pontiac  manufacturer_porsche  manufacturer_ram  \
# 0             -0.088675             -0.054738         -0.186137
# 1             -0.088675             -0.054738         -0.186137
# 2             -0.088675             -0.054738         -0.186137
# 3             -0.088675             -0.054738         -0.186137
# 4             -0.088675             -0.054738         -0.186137
#
#    manufacturer_rover  manufacturer_saturn  manufacturer_subaru  \
# 0           -0.060819            -0.060819            -0.150195
# 1           -0.060819            -0.060819            -0.150195
# 2           -0.060819            -0.060819            -0.150195
# 3           -0.060819            -0.060819            -0.150195
# 4           -0.060819            -0.060819            -0.150195
#
#    manufacturer_tesla  manufacturer_toyota  manufacturer_unknown  \
# 0           -0.018128             3.325272             -0.212798
# 1           -0.018128            -0.300727             -0.212798
# 2           -0.018128            -0.300727             -0.212798
# 3           -0.018128            -0.300727             -0.212798
# 4           -0.018128            -0.300727             -0.212798
#
#    manufacturer_volkswagen  manufacturer_volvo  condition_excellent  \
# 0                -0.140587           -0.084215             1.113379
# 1                -0.140587           -0.084215             1.113379
# 2                -0.140587           -0.084215            -0.898166
# 3                -0.140587           -0.084215             1.113379
# 4                -0.140587           -0.084215            -0.898166
#
#    condition_fair  condition_good  condition_like new  condition_new  \
# 0       -0.187901       -0.821626           -0.348711      -0.073258
# 1       -0.187901       -0.821626           -0.348711      -0.073258
# 2       -0.187901        1.217098           -0.348711      -0.073258
# 3       -0.187901       -0.821626           -0.348711      -0.073258
# 4       -0.187901        1.217098           -0.348711      -0.073258
#
#    condition_salvage  cylinders_10 cylinders  cylinders_12 cylinders  \
# 0          -0.051332                -0.08996               -0.027385
# 1          -0.051332                -0.08996               -0.027385
# 2          -0.051332                -0.08996               -0.027385
# 3          -0.051332                -0.08996               -0.027385
# 4          -0.051332                -0.08996               -0.027385
#
#    cylinders_3 cylinders  cylinders_4 cylinders  cylinders_5 cylinders  \
# 0              -0.047032              -0.668709               -0.09259
# 1              -0.047032              -0.668709               -0.09259
# 2              -0.047032              -0.668709               -0.09259
# 3              -0.047032              -0.668709               -0.09259
# 4              -0.047032               1.495419               -0.09259
#
#    cylinders_6 cylinders  cylinders_8 cylinders  cylinders_other  fuel_diesel  \
# 0               1.315063              -0.657750        -0.056227    -0.262554
# 1              -0.760420               1.520335        -0.056227    -0.262554
# 2              -0.760420               1.520335        -0.056227     3.808743
# 3               1.315063              -0.657750        -0.056227    -0.262554
# 4              -0.760420              -0.657750        -0.056227    -0.262554
#
#    fuel_electric  fuel_gas  fuel_hybrid  fuel_other  title_status_clean  \
# 0      -0.041316  0.318136    -0.107066   -0.120798            0.238361
# 1      -0.041316  0.318136    -0.107066   -0.120798            0.238361
# 2      -0.041316 -3.143306    -0.107066   -0.120798            0.238361
# 3      -0.041316  0.318136    -0.107066   -0.120798            0.238361
# 4      -0.041316  0.318136    -0.107066   -0.120798            0.238361
#
#    title_status_lien  title_status_missing  title_status_parts only  \
# 0          -0.088144             -0.048649                -0.023984
# 1          -0.088144             -0.048649                -0.023984
# 2          -0.088144             -0.048649                -0.023984
# 3          -0.088144             -0.048649                -0.023984
# 4          -0.088144             -0.048649                -0.023984
#
#    title_status_rebuilt  title_status_salvage  transmission_automatic  \
# 0             -0.175541             -0.115756                0.459369
# 1             -0.175541             -0.115756                0.459369
# 2             -0.175541             -0.115756                0.459369
# 3             -0.175541             -0.115756                0.459369
# 4             -0.175541             -0.115756                0.459369
#
#    transmission_manual  transmission_other  transmission_unknown  drive_4wd  \
# 0            -0.290045           -0.326904             -0.010132    1.19272
# 1            -0.290045           -0.326904             -0.010132    1.19272
# 2            -0.290045           -0.326904             -0.010132   -0.83842
# 3            -0.290045           -0.326904             -0.010132    1.19272
# 4            -0.290045           -0.326904             -0.010132   -0.83842
#
#    drive_fwd  drive_rwd  type_SUV  type_bus  type_convertible  type_coupe  \
# 0  -0.713967  -0.576702  1.908514 -0.042302         -0.171334   -0.272686
# 1  -0.713967  -0.576702 -0.523968 -0.042302         -0.171334   -0.272686
# 2  -0.713967   1.733997 -0.523968 -0.042302         -0.171334   -0.272686
# 3  -0.713967  -0.576702 -0.523968 -0.042302         -0.171334   -0.272686
# 4   1.400625  -0.576702 -0.523968 -0.042302         -0.171334   -0.272686
#
#    type_hatchback  type_mini-van  type_offroad  type_other  type_pickup  \
# 0       -0.193537      -0.148363     -0.061412   -0.161328    -0.331692
# 1       -0.193537      -0.148363     -0.061412   -0.161328    -0.331692
# 2       -0.193537      -0.148363     -0.061412   -0.161328     3.014843
# 3       -0.193537      -0.148363     -0.061412   -0.161328     3.014843
# 4       -0.193537      -0.148363     -0.061412   -0.161328    -0.331692
#
#    type_sedan  type_truck  type_unknown  type_van  type_wagon  \
# 0   -0.570696   -0.386791     -0.278593 -0.166902   -0.157673
# 1   -0.570696    2.585373     -0.278593 -0.166902   -0.157673
# 2   -0.570696   -0.386791     -0.278593 -0.166902   -0.157673
# 3   -0.570696   -0.386791     -0.278593 -0.166902   -0.157673
# 4   -0.570696   -0.386791      3.589466 -0.166902   -0.157673
#
#    paint_color_black  paint_color_blue  paint_color_brown  paint_color_custom  \
# 0           2.094360         -0.347914          -0.169676           -0.149945
# 1           2.094360         -0.347914          -0.169676           -0.149945
# 2          -0.477473         -0.347914          -0.169676           -0.149945
# 3          -0.477473         -0.347914          -0.169676           -0.149945
# 4          -0.477473         -0.347914          -0.169676           -0.149945
#
#    paint_color_green  paint_color_grey  paint_color_orange  \
# 0          -0.186225         -0.341314           -0.082151
# 1          -0.186225         -0.341314           -0.082151
# 2          -0.186225         -0.341314           -0.082151
# 3          -0.186225         -0.341314           -0.082151
# 4          -0.186225          2.929850           -0.082151
#
#    paint_color_purple  paint_color_red  paint_color_silver  paint_color_white  \
# 0           -0.057229        -0.348359           -0.407837          -0.574980
# 1           -0.057229        -0.348359           -0.407837          -0.574980
# 2           -0.057229        -0.348359           -0.407837           1.739192
# 3           -0.057229        -0.348359            2.451957          -0.574980
# 4           -0.057229        -0.348359           -0.407837          -0.574980
#
#    paint_color_yellow
# 0           -0.096784
# 1           -0.096784
# 2           -0.096784
# 3           -0.096784
# 4           -0.096784

# %%
#Task 1.2.2
yTrainModel.head()
# Out:
#        price
# 0   9.259226
# 1  10.307318
# 2  10.668862
# 3  10.542733
# 4   8.682877

# %%
yTrainModel
# Out:
#            price
# 0       9.259226
# 1      10.307318
# 2      10.668862
# 3      10.542733
# 4       8.682877
# ...          ...
# 97407   7.673688
# 97408  10.081676
# 97409   8.412055
# 97410   8.497195
# 97411   8.516393
#
# [97412 rows x 1 columns]

# %%
#Task 1.2.3
xTestModel.head()
# Out:
#        year  odometer       lat      long  manufacturer_acura  \
# 0  0.290559  0.157638 -0.997091 -0.259257           -0.101225
# 1 -0.285273  0.661724 -1.582191 -0.168241           -0.101225
# 2  0.194587  0.139725 -0.531630 -0.310340           -0.101225
# 3  0.002643  0.670487 -0.768994 -0.283013           -0.101225
# 4  0.290559  0.272597  0.959330  1.273264           -0.101225
#
#    manufacturer_alfa-romeo  manufacturer_aston-martin  manufacturer_audi  \
# 0                -0.019755                  -0.007165          -0.102868
# 1                -0.019755                  -0.007165          -0.102868
# 2                -0.019755                  -0.007165          -0.102868
# 3                -0.019755                  -0.007165          -0.102868
# 4                -0.019755                  -0.007165          -0.102868
#
#    manufacturer_bmw  manufacturer_buick  manufacturer_cadillac  \
# 0         -0.163293           -0.113132              -0.117609
# 1         -0.163293           -0.113132              -0.117609
# 2         -0.163293           -0.113132              -0.117609
# 3         -0.163293           -0.113132              -0.117609
# 4         -0.163293           -0.113132              -0.117609
#
#    manufacturer_chevrolet  manufacturer_chrysler  manufacturer_datsun  \
# 0               -0.415409              -0.130696             -0.01433
# 1               -0.415409              -0.130696             -0.01433
# 2                2.407264              -0.130696             -0.01433
# 3               -0.415409              -0.130696             -0.01433
# 4               -0.415409              -0.130696             -0.01433
#
#    manufacturer_dodge  manufacturer_ferrari  manufacturer_fiat  \
# 0            -0.18831             -0.013212          -0.037115
# 1            -0.18831             -0.013212          -0.037115
# 2            -0.18831             -0.013212          -0.037115
# 3            -0.18831             -0.013212          -0.037115
# 4            -0.18831             -0.013212          -0.037115
#
#    manufacturer_ford  manufacturer_gmc  manufacturer_harley-davidson  \
# 0           2.173103         -0.204656                     -0.017552
# 1          -0.460172         -0.204656                     -0.017552
# 2          -0.460172         -0.204656                     -0.017552
# 3          -0.460172          4.886244                     -0.017552
# 4          -0.460172         -0.204656                     -0.017552
#
#    manufacturer_honda  manufacturer_hyundai  manufacturer_infiniti  \
# 0           -0.239705             -0.146911              -0.109493
# 1           -0.239705              6.806859              -0.109493
# 2           -0.239705             -0.146911              -0.109493
# 3           -0.239705             -0.146911              -0.109493
# 4           -0.239705             -0.146911              -0.109493
#
#    manufacturer_jaguar  manufacturer_jeep  manufacturer_kia  \
# 0            -0.055766           -0.22781         -0.130656
# 1            -0.055766           -0.22781         -0.130656
# 2            -0.055766           -0.22781         -0.130656
# 3            -0.055766           -0.22781         -0.130656
# 4            -0.055766           -0.22781         -0.130656
#
#    manufacturer_land rover  manufacturer_lexus  manufacturer_lincoln  \
# 0                -0.009063           -0.134148             -0.097484
# 1                -0.009063           -0.134148             -0.097484
# 2                -0.009063           -0.134148             -0.097484
# 3                -0.009063           -0.134148             -0.097484
# 4                -0.009063           -0.134148             -0.097484
#
#    manufacturer_mazda  manufacturer_mercedes-benz  manufacturer_mercury  \
# 0           -0.106328                   -0.155921             -0.064132
# 1           -0.106328                   -0.155921             -0.064132
# 2           -0.106328                   -0.155921             -0.064132
# 3           -0.106328                   -0.155921             -0.064132
# 4           -0.106328                   -0.155921             -0.064132
#
#    manufacturer_mini  manufacturer_mitsubishi  manufacturer_nissan  \
# 0          -0.066587                -0.084524            -0.230687
# 1          -0.066587                -0.084524            -0.230687
# 2          -0.066587                -0.084524            -0.230687
# 3          -0.066587                -0.084524            -0.230687
# 4          -0.066587                -0.084524             4.334875
#
#    manufacturer_pontiac  manufacturer_porsche  manufacturer_ram  \
# 0             -0.088675             -0.054738         -0.186137
# 1             -0.088675             -0.054738         -0.186137
# 2             -0.088675             -0.054738         -0.186137
# 3             -0.088675             -0.054738         -0.186137
# 4             -0.088675             -0.054738         -0.186137
#
#    manufacturer_rover  manufacturer_saturn  manufacturer_subaru  \
# 0           -0.060819            -0.060819            -0.150195
# 1           -0.060819            -0.060819            -0.150195
# 2           -0.060819            -0.060819            -0.150195
# 3           -0.060819            -0.060819            -0.150195
# 4           -0.060819            -0.060819            -0.150195
#
#    manufacturer_tesla  manufacturer_toyota  manufacturer_unknown  \
# 0           -0.018128            -0.300727             -0.212798
# 1           -0.018128            -0.300727             -0.212798
# 2           -0.018128            -0.300727             -0.212798
# 3           -0.018128            -0.300727             -0.212798
# 4           -0.018128            -0.300727             -0.212798
#
#    manufacturer_volkswagen  manufacturer_volvo  condition_excellent  \
# 0                -0.140587           -0.084215            -0.898166
# 1                -0.140587           -0.084215            -0.898166
# 2                -0.140587           -0.084215            -0.898166
# 3                -0.140587           -0.084215             1.113379
# 4                -0.140587           -0.084215             1.113379
#
#    condition_fair  condition_good  condition_like new  condition_new  \
# 0       -0.187901        1.217098           -0.348711      -0.073258
# 1        5.321964       -0.821626           -0.348711      -0.073258
# 2       -0.187901        1.217098           -0.348711      -0.073258
# 3       -0.187901       -0.821626           -0.348711      -0.073258
# 4       -0.187901       -0.821626           -0.348711      -0.073258
#
#    condition_salvage  cylinders_10 cylinders  cylinders_12 cylinders  \
# 0          -0.051332                -0.08996               -0.027385
# 1          -0.051332                -0.08996               -0.027385
# 2          -0.051332                -0.08996               -0.027385
# 3          -0.051332                -0.08996               -0.027385
# 4          -0.051332                -0.08996               -0.027385
#
#    cylinders_3 cylinders  cylinders_4 cylinders  cylinders_5 cylinders  \
# 0              -0.047032               1.495419               -0.09259
# 1              -0.047032               1.495419               -0.09259
# 2              -0.047032               1.495419               -0.09259
# 3              -0.047032              -0.668709               -0.09259
# 4              -0.047032              -0.668709               -0.09259
#
#    cylinders_6 cylinders  cylinders_8 cylinders  cylinders_other  fuel_diesel  \
# 0              -0.760420              -0.657750        -0.056227    -0.262554
# 1              -0.760420              -0.657750        -0.056227    -0.262554
# 2              -0.760420              -0.657750        -0.056227    -0.262554
# 3              -0.760420               1.520335        -0.056227    -0.262554
# 4               1.315063              -0.657750        -0.056227    -0.262554
#
#    fuel_electric  fuel_gas  fuel_hybrid  fuel_other  title_status_clean  \
# 0      -0.041316  0.318136    -0.107066   -0.120798            0.238361
# 1      -0.041316  0.318136    -0.107066   -0.120798            0.238361
# 2      -0.041316  0.318136    -0.107066   -0.120798            0.238361
# 3      -0.041316  0.318136    -0.107066   -0.120798            0.238361
# 4      -0.041316  0.318136    -0.107066   -0.120798            0.238361
#
#    title_status_lien  title_status_missing  title_status_parts only  \
# 0          -0.088144             -0.048649                -0.023984
# 1          -0.088144             -0.048649                -0.023984
# 2          -0.088144             -0.048649                -0.023984
# 3          -0.088144             -0.048649                -0.023984
# 4          -0.088144             -0.048649                -0.023984
#
#    title_status_rebuilt  title_status_salvage  transmission_automatic  \
# 0             -0.175541             -0.115756                0.459369
# 1             -0.175541             -0.115756               -2.176900
# 2             -0.175541             -0.115756                0.459369
# 3             -0.175541             -0.115756                0.459369
# 4             -0.175541             -0.115756                0.459369
#
#    transmission_manual  transmission_other  transmission_unknown  drive_4wd  \
# 0            -0.290045           -0.326904             -0.010132   -0.83842
# 1             3.447737           -0.326904             -0.010132   -0.83842
# 2            -0.290045           -0.326904             -0.010132   -0.83842
# 3            -0.290045           -0.326904             -0.010132    1.19272
# 4            -0.290045           -0.326904             -0.010132    1.19272
#
#    drive_fwd  drive_rwd  type_SUV  type_bus  type_convertible  type_coupe  \
# 0   1.400625  -0.576702 -0.523968 -0.042302         -0.171334   -0.272686
# 1   1.400625  -0.576702 -0.523968 -0.042302         -0.171334    3.667224
# 2   1.400625  -0.576702 -0.523968 -0.042302         -0.171334   -0.272686
# 3  -0.713967  -0.576702 -0.523968 -0.042302         -0.171334   -0.272686
# 4  -0.713967  -0.576702 -0.523968 -0.042302         -0.171334   -0.272686
#
#    type_hatchback  type_mini-van  type_offroad  type_other  type_pickup  \
# 0       -0.193537      -0.148363     -0.061412   -0.161328    -0.331692
# 1       -0.193537      -0.148363     -0.061412   -0.161328    -0.331692
# 2       -0.193537      -0.148363     -0.061412   -0.161328    -0.331692
# 3       -0.193537      -0.148363     -0.061412   -0.161328    -0.331692
# 4       -0.193537       6.740244     -0.061412   -0.161328    -0.331692
#
#    type_sedan  type_truck  type_unknown  type_van  type_wagon  \
# 0    1.752246   -0.386791     -0.278593 -0.166902   -0.157673
# 1   -0.570696   -0.386791     -0.278593 -0.166902   -0.157673
# 2    1.752246   -0.386791     -0.278593 -0.166902   -0.157673
# 3   -0.570696    2.585373     -0.278593 -0.166902   -0.157673
# 4   -0.570696   -0.386791     -0.278593 -0.166902   -0.157673
#
#    paint_color_black  paint_color_blue  paint_color_brown  paint_color_custom  \
# 0          -0.477473         -0.347914          -0.169676           -0.149945
# 1          -0.477473         -0.347914          -0.169676           -0.149945
# 2          -0.477473         -0.347914          -0.169676           -0.149945
# 3          -0.477473         -0.347914          -0.169676           -0.149945
# 4          -0.477473          2.874275          -0.169676           -0.149945
#
#    paint_color_green  paint_color_grey  paint_color_orange  \
# 0          -0.186225         -0.341314           -0.082151
# 1          -0.186225         -0.341314           -0.082151
# 2          -0.186225          2.929850           -0.082151
# 3          -0.186225         -0.341314           -0.082151
# 4          -0.186225         -0.341314           -0.082151
#
#    paint_color_purple  paint_color_red  paint_color_silver  paint_color_white  \
# 0           -0.057229        -0.348359           -0.407837           1.739192
# 1           -0.057229        -0.348359            2.451957          -0.574980
# 2           -0.057229        -0.348359           -0.407837          -0.574980
# 3           -0.057229        -0.348359           -0.407837           1.739192
# 4           -0.057229        -0.348359           -0.407837          -0.574980
#
#    paint_color_yellow
# 0           -0.096784
# 1           -0.096784
# 2           -0.096784
# 3           -0.096784
# 4           -0.096784

# %%
#Task 1.2.4
yTestModel.head()
# Out:
#       price
# 0  8.853523
# 1  6.311735
# 2  7.313887
# 3  0.000000
# 4  0.000000

# %%
#Task 1.3.1
xTrainModel.shape
# Out:
# (97412, 104)

# %%
#Task 1.3.2
yTrainModel.shape
# Out:
# (97412, 1)

# %%
#Task 1.3.3
xTestModel.shape
# Out:
# (32471, 104)

# %%
#Task 1.3.4
yTestModel.shape
# Out:
# (32471, 1)

# %% [markdown]
# linear regression - used for continous independant and dependand variable is continous or categorecial

# %% [markdown]
# # Task 2.0
#
# Linear Regression

# %%
# Task 2.1

# Create the model: make a variable called rModel, and use it linear_model.LinearRegression appropriately
rModel = linear_model.LinearRegression(normalize=True)

# %%
# Task 2.2

# We now want to train the model on our test data.
rModel.fit(xTrainModel,yTrainModel)
# Out:
# LinearRegression(normalize=True)

# %%
# Task 2.3

# Evaluate the model  
print(rModel.score(xTrainModel,yTrainModel))
# Out:
# 0.09022797359191126

# %%
# Task 2.4

# Use the model to make predictions about our test data
y_pred = rModel.predict(xTestModel)
y_pred
# Out:
# array([[8.29751953],
#        [7.43819794],
#        [8.31063446],
#        ...,
#        [9.0641211 ],
#        [8.76644501],
#        [8.67928681]])

# %%
# Task 2.5

# Let's plot the predictions against the actual result. Use scatter()
plt.scatter(yTestModel,y_pred)

# %%
# Task 2.6

#r2 or mean square error report or root mean square
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())


#test Train data

# %%
# Task 2.7

#test data



# Put the predictions & actual values into a dataframe
matches = pd.DataFrame(yTestModel)
matches.rename(columns={'price':'actual'},inplace=True)
matches["predictions"]=y_pred

rmse(matches["actual"],matches['predictions'])
# Out:
# 2.050783794605163

# %% [markdown]
# #test data
#
#
#
# # Put the predictions & actual values into a dataframe
# matches = pd.DataFrame(yTestModel)
# matches.rename(columns={'fixed.acidity':'actual'},inplace=True)
# matches["predictions"]=y_pred
#
# rmse(matches["actual"],matches['predictions'])

# %% [markdown]
# # Task 3.0
#
# Random Forest

# %%
#scale data
from sklearn import preprocessing
import numpy as np
# build scaler based on training data and apply it to test data to then also scale the test data
scaler = preprocessing.StandardScaler().fit(xTrainModel)
X_train_scaled=scaler.transform(xTrainModel)
X_test_scaled=scaler.transform(xTestModel)

# %%
X_train_scaled
# Out:
# array([[-0.57318855,  0.66492533,  0.41829181, ..., -0.40783749,
#         -0.5749795 , -0.09678377],
#        [ 0.48250324,  0.46922959, -0.91550231, ..., -0.40783749,
#         -0.5749795 , -0.09678377],
#        [ 0.1945873 ,  0.35423443,  0.85822677, ..., -0.40783749,
#          1.73919243, -0.09678377],
#        ...,
#        [ 0.00264334,  0.85065612,  0.70206567, ..., -0.40783749,
#         -0.5749795 , -0.09678377],
#        [-0.09332864,  0.59193293, -1.44274678, ..., -0.40783749,
#         -0.5749795 , -0.09678377],
#        [-0.66916053, -0.11859491,  0.26953974, ..., -0.40783749,
#         -0.5749795 , -0.09678377]])

# %%
yTrainModel
# Out:
#            price
# 0       9.259226
# 1      10.307318
# 2      10.668862
# 3      10.542733
# 4       8.682877
# ...          ...
# 97407   7.673688
# 97408  10.081676
# 97409   8.412055
# 97410   8.497195
# 97411   8.516393
#
# [97412 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=300, random_state = 1,n_jobs=-1,class_weight= 'balanced')
#verify 2 selection

model_res = clf.fit(X_train_scaled, yTrainModel)
y_pred2 = model_res.predict(X_test_scaled)
y_pred_prob = model_res.predict_proba(X_test_scaled)
lr_probs = y_pred_prob[:,1]
ac = accuracy_score(yTestModel, y_pred2)

f1 = f1_score(yTestModel, y_pred2, average='weighted')
#cm = confusion_matrix(yTestModel, y_pred2)

print('Random Forest: Accuracy=%.3f' % (ac))

print('Random Forest: f1-score=%.3f' % (f1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-2ef8eecb6369> in <module>
#       4 #verify 2 selection
#       5
# ----> 6 model_res = clf.fit(X_train_scaled, yTrainModel)
#       7 y_pred2 = model_res.predict(X_test_scaled)
#       8 y_pred_prob = model_res.predict_proba(X_test_scaled)
#
# D:\ProgramData\Anaconda3\envs\springboard\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     329         self.n_outputs_ = y.shape[1]
#     330
# --> 331         y, expanded_class_weight = self._validate_y_class_weight(y)
#     332
#     333         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# D:\ProgramData\Anaconda3\envs\springboard\lib\site-packages\sklearn\ensemble\_forest.py in _validate_y_class_weight(self, y)
#     557
#     558     def _validate_y_class_weight(self, y):
# --> 559         check_classification_targets(y)
#     560
#     561         y = np.copy(y)
#
# D:\ProgramData\Anaconda3\envs\springboard\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     181     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     182                       'multilabel-indicator', 'multilabel-sequences']:
# --> 183         raise ValueError("Unknown label type: %r" % y_type)
#     184
#     185
#
# ValueError: Unknown label type: 'continuous'

# %% [markdown]
# # Put the predictions & actual values into a dataframe
# matches = pd.DataFrame(yTestModel)
# matches.rename(columns={'price':'actual'},inplace=True)
# matches["predictions"]=y_pred2
#
# rmse(matches["actual"],matches['predictions'])

# %% [markdown]
# # Random Forest Regressor

# %%
#Task 3.1

# %% [markdown]
# xTrainModel ~ train_features
# yTrainModel ~ train_labels
# xTestModel  ~ test_features
# yTestModel  ~ test_labels

# %% [markdown]
# print('Training Features Shape:', train_features.shape)
# print('Training Labels Shape:', train_labels.shape)
# print('Testing Features Shape:', test_features.shape)
# print('Testing Labels Shape:', test_labels.shape)
# Training Features Shape: (261, 14)
# Training Labels Shape: (261,)
# Testing Features Shape: (87, 14)
# Testing Labels Shape: (87,)

# %% [markdown]
# # The baseline predictions are the historical averages
# baseline_preds = test_features[:, feature_list.index('average')]
# # Baseline errors, and display average baseline error
# baseline_errors = abs(baseline_preds - test_labels)
# print('Average baseline error: ', round(np.mean(baseline_errors), 2))
# Average baseline error:  5.06 degrees.

# %% [markdown]
# # Import the model we are using
# from sklearn.ensemble import RandomForestRegressor
# # Instantiate model with 1000 decision trees
# rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# # Train the model on training data
# rf.fit(train_features, train_labels);

# %% [markdown]
# # Use the forest's predict method on the test data
# predictions = rf.predict(test_features)
# # Calculate the absolute errors
# errors = abs(predictions - test_labels)
# # Print out the mean absolute error (mae)
# print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Mean Absolute Error: 3.83 degrees.

# %%
RandomForestRegModel = RandomeForestRegressor()
RandomForestRegModel.fit(xTrainModel,yTrainModel)

# %%
y_pred2 = RandomForestRegModel.predict(xTestModel)
y_pred2

# %%
y_pred3
# Out:
# array([ 8.76375207,  7.68093877,  8.70394096, ..., 10.43043693,
#         9.66027562,  8.76548799])

# %%
yTestModel
# Out:
#            price
# 0       8.853523
# 1       6.311735
# 2       7.313887
# 3       0.000000
# 4       0.000000
# ...          ...
# 32466   8.779711
# 32467   0.693147
# 32468  10.529453
# 32469   9.680344
# 32470   7.783641
#
# [32471 rows x 1 columns]

# %% [markdown]
# # Task 4.0
#
# Support Vector Regression

# %%
#reimport yTestModel
yTestModel=pd.read_csv(r'.\Data\UsedCarData\y_Test_Output.csv',header=0)

# %%
# Task 4.1

SupportVectorRegModel=SVR()
SupportVectorRegModel.fit(xTrainModel,yTrainModel)
# Out:
# SVR()

# %%
# Task 4.2

y_pred3 = SupportVectorRegModel.predict(xTestModel)
y_pred3
# Out:
# array([ 8.76375207,  7.68093877,  8.70394096, ..., 10.43043693,
#         9.66027562,  8.76548799])

# %%
# Task 4.3

mse = mean_squared_error(yTestModel, y_pred3)

# %%
# Task 4.4

rmse=np.sqrt(mse)
rmse
# Out:
# 2.024577511112161

# %%
used on of the r2 or mean square error

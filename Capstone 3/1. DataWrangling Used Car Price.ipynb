# %% [markdown]
# With this dataset i will predict if a vehicle will increase or decrease.  It is currently in the news with lack of supply of chips, it is causing vehicle prices to increase.

# %%
#Task 1
#import pandas
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
import numpy as np
import os
import sklearn


##import inforamtion from Kaggle 
usedVehicle = pd.read_csv(r'.\Data\UsedCarData\vehicles.csv',header=0)

# %%
#Task 1.1
usedVehicle
# Out:
#                 id                                                url  \
# 0       7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1       7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2       7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3       7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4       7210384030  https://greensboro.craigslist.org/cto/d/trinit...
# ...            ...                                                ...
# 426875  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426876  7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426877  7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426878  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426879  7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#                         region                         region_url  price  \
# ...

# %%
#Task 1.2
#View the column information and see there is a lot of NaN.  I  need review how many column will need to be
#replaced or dropped.  there are possible 26 features
usedVehicle.head(10)
# Out:
#            id                                                url  \
# 0  7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1  7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2  7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3  7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4  7210384030  https://greensboro.craigslist.org/cto/d/trinit...
# 5  7222379453  https://hudsonvalley.craigslist.org/cto/d/west...
# 6  7221952215  https://hudsonvalley.craigslist.org/cto/d/west...
# 7  7220195662  https://hudsonvalley.craigslist.org/cto/d/poug...
# 8  7209064557  https://medford.craigslist.org/cto/d/grants-pa...
# 9  7219485069  https://erie.craigslist.org/cto/d/erie-2012-su...
#
#                    region                           region_url  price  year  \
# 0                prescott      https://prescott.craigslist.org   6000   NaN
# 1            fayetteville         https://fayar.craigslist.org  11900   NaN
# ...

# %%
# Task 1.3
#
usedVehicle.describe()
# Out:
#                  id         price           year      odometer  county  \
# count  4.268800e+05  4.268800e+05  425675.000000  4.224800e+05     0.0
# mean   7.311487e+09  7.519903e+04    2011.235191  9.804333e+04     NaN
# std    4.473170e+06  1.218228e+07       9.452120  2.138815e+05     NaN
# min    7.207408e+09  0.000000e+00    1900.000000  0.000000e+00     NaN
# 25%    7.308143e+09  5.900000e+03    2008.000000  3.770400e+04     NaN
# 50%    7.312621e+09  1.395000e+04    2013.000000  8.554800e+04     NaN
# 75%    7.315254e+09  2.648575e+04    2017.000000  1.335425e+05     NaN
# max    7.317101e+09  3.736929e+09    2022.000000  1.000000e+07     NaN
#
#                  lat           long
# count  420331.000000  420331.000000
# mean       38.493940     -94.748599
# std         5.841533      18.365462
# min       -84.122245    -159.827728
# 25%        34.601900    -111.939847
# 50%        39.150100     -88.432600
# 75%        42.398900     -80.832039
# ...

# %%
# Task 1.4
#
usedVehicle.columns
# Out:
# Index(['id', 'url', 'region', 'region_url', 'price', 'year', 'manufacturer',
#        'model', 'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'VIN', 'drive', 'size', 'type', 'paint_color',
#        'image_url', 'description', 'county', 'state', 'lat', 'long',
#        'posting_date'],
#       dtype='object')

# %%
# Task 1.5
#rerun
usedVehicle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   url           426880 non-null  object
#  2   region        426880 non-null  object
#  3   region_url    426880 non-null  object
#  4   price         426880 non-null  int64
#  5   year          425675 non-null  float64
#  6   manufacturer  409234 non-null  object
#  7   model         421603 non-null  object
#  8   condition     252776 non-null  object
#  9   cylinders     249202 non-null  object
#  10  fuel          423867 non-null  object
#  11  odometer      422480 non-null  float64
#  12  title_status  418638 non-null  object
#  13  transmission  424324 non-null  object
#  14  VIN           265838 non-null  object
#  15  drive         296313 non-null  object
#  16  size          120519 non-null  object
# ...

# %%
# Task 1.6
usedVehicle.type
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#             ...
# 426875        sedan
# 426876        sedan
# 426877    hatchback
# 426878        sedan
# 426879        coupe
# Name: type, Length: 426880, dtype: object

# %% [markdown]
# Section 2 delete column or clear NaN
#
# I am dropping the URL column as the website path of listing is not needed.

# %%
#Task 2.0
#get a list of columns that is NaN
#  There is a possible of  426880 and county is 426880 NaN.  
#perlooking at data i should drop size because there is 75% data is missing 


bbb=usedVehicle.isna().sum()
bbb.sort_values(ascending = False)
# Out:
# county          426880
# size            306361
# cylinders       177678
# condition       174104
# VIN             161042
# drive           130567
# paint_color     130203
# type             92858
# manufacturer     17646
# title_status      8242
# lat               6549
# long              6549
# model             5277
# odometer          4400
# fuel              3013
# transmission      2556
# year              1205
# description         70
# image_url           68
# posting_date        68
# url                  0
# price                0
# state                0
# region_url           0
# region               0
# id                   0
# dtype: int64

# %%
#Task 2.1
#i will need to fill size of NaN vehicle to unknown
AA=usedVehicle.loc[usedVehicle['size'].notnull()]
AA
# Out:
#                 id                                                url  \
# 31      7316356412  https://auburn.craigslist.org/cto/d/auburn-uni...
# 46      7315039307  https://auburn.craigslist.org/ctd/d/auburn-999...
# 55      7314560853  https://auburn.craigslist.org/cto/d/auburn-200...
# 59      7313406529  https://auburn.craigslist.org/cto/d/auburn-hon...
# 65      7312847466  https://auburn.craigslist.org/cto/d/opelika-20...
# ...            ...                                                ...
# 426809  7302963273  https://wyoming.craigslist.org/cto/d/jackson-1...
# 426831  7302384818  https://wyoming.craigslist.org/cto/d/cheyenne-...
# 426833  7302338378  https://wyoming.craigslist.org/cto/d/kirby-jag...
# 426836  7302301268  https://wyoming.craigslist.org/ctd/d/dassel-20...
# 426838  7302198494  https://wyoming.craigslist.org/cto/d/cheyenne-...
#
#          region                      region_url  price    year manufacturer  \
# ...

# %%
#Task 2.1
usedVehicle[['VIN','year','model','size','title_status','drive','type','posting_date']]
# Out:
#                       VIN    year                     model size title_status  \
# 0                     NaN     NaN                       NaN  NaN          NaN
# 1                     NaN     NaN                       NaN  NaN          NaN
# 2                     NaN     NaN                       NaN  NaN          NaN
# 3                     NaN     NaN                       NaN  NaN          NaN
# 4                     NaN     NaN                       NaN  NaN          NaN
# ...                   ...     ...                       ...  ...          ...
# 426875  1N4AA6AV6KC367801  2019.0         maxima s sedan 4d  NaN        clean
# 426876  7JR102FKXLG042696  2020.0  s60 t5 momentum sedan 4d  NaN        clean
# 426877  1GYFZFR46LF088296  2020.0          xt4 sport suv 4d  NaN        clean
# 426878  58ABK1GG4JU103853  2018.0           es 350 sedan 4d  NaN        clean
# 426879  WBA4J1C58KBM14708  2019.0  4 series 430i gran coupe  NaN        clean
#
# ...

# %%
#Task 2.2


#Dropping this column because the NaN is 426880.  That meant the column is all NaN so unnecessary column
usedVehicle2 = usedVehicle.drop(['county','id','url','image_url','region_url','size','description','VIN'],axis=1)

# %%
#Task 2.3

usedVehicle2
# Out:
#                         region  price    year manufacturer  \
# 0                     prescott   6000     NaN          NaN
# 1                 fayetteville  11900     NaN          NaN
# 2                 florida keys  21000     NaN          NaN
# 3       worcester / central MA   1500     NaN          NaN
# 4                   greensboro   4900     NaN          NaN
# ...                        ...    ...     ...          ...
# 426875                 wyoming  23590  2019.0       nissan
# 426876                 wyoming  30590  2020.0        volvo
# 426877                 wyoming  34990  2020.0     cadillac
# 426878                 wyoming  28990  2018.0        lexus
# 426879                 wyoming  30590  2019.0          bmw
#
#                            model condition    cylinders    fuel  odometer  \
# 0                            NaN       NaN          NaN     NaN       NaN
# 1                            NaN       NaN          NaN     NaN       NaN
# ...

# %%
##Task 2.4

bbb=usedVehicle2.isna().sum()
bbb.sort_values(ascending = False)
# Out:
# cylinders       177678
# condition       174104
# drive           130567
# paint_color     130203
# type             92858
# manufacturer     17646
# title_status      8242
# lat               6549
# long              6549
# model             5277
# odometer          4400
# fuel              3013
# transmission      2556
# year              1205
# posting_date        68
# state                0
# price                0
# region               0
# dtype: int64

# %%
#Task 2.5
usedVehicle2.dropna(subset =['year','odometer','long','lat','posting_date','model','cylinders','condition','drive','paint_color'],inplace = True)

# %%
##Task 2.5.1

ccc=usedVehicle2.isna().sum()
ccc.sort_values(ascending = False)
# Out:
# type            9361
# manufacturer    5593
# transmission      11
# region             0
# long               0
# lat                0
# state              0
# paint_color        0
# drive              0
# title_status       0
# price              0
# odometer           0
# fuel               0
# cylinders          0
# condition          0
# model              0
# year               0
# posting_date       0
# dtype: int64

# %%
#Task 2.6.0
# replace with int with String.  lat and long  (mean of column)
usedVehicle2.fillna({'manufacturer':'unknown','type':'unknown','transmission':'unknown'},inplace = True)

# %% [markdown]
# #dropping if it isna where the column data is in year, odometer, long, lat of vehicle because if i do not know year it is a important feature.

# %%
#Task 2.6.1
usedVehicle2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129883 entries, 31 to 426878
# Data columns (total 18 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   region        129883 non-null  object
#  1   price         129883 non-null  int64
#  2   year          129883 non-null  float64
#  3   manufacturer  129883 non-null  object
#  4   model         129883 non-null  object
#  5   condition     129883 non-null  object
#  6   cylinders     129883 non-null  object
#  7   fuel          129883 non-null  object
#  8   odometer      129883 non-null  float64
#  9   title_status  129883 non-null  object
#  10  transmission  129883 non-null  object
#  11  drive         129883 non-null  object
#  12  type          129883 non-null  object
#  13  paint_color   129883 non-null  object
#  14  state         129883 non-null  object
#  15  lat           129883 non-null  float64
#  16  long          129883 non-null  float64
# ...

# %%
#Task 2.6.2
usedVehicle2
# Out:
#          region  price    year manufacturer                        model  \
# 31       auburn  15000  2013.0         ford                    f-150 xlt
# 32       auburn  27990  2012.0          gmc  sierra 2500 hd extended cab
# 33       auburn  34590  2016.0    chevrolet        silverado 1500 double
# 34       auburn  35000  2019.0       toyota                       tacoma
# 35       auburn  29990  2016.0    chevrolet        colorado extended cab
# ...         ...    ...     ...          ...                          ...
# 426863  wyoming  25590  2017.0      unknown     Genesis G80 3.8 Sedan 4D
# 426866  wyoming  32990  2016.0     infiniti        qx80 sport utility 4d
# 426868  wyoming      0  2010.0       toyota                        venza
# 426874  wyoming  33590  2018.0        lexus              gs 350 sedan 4d
# 426878  wyoming  28990  2018.0        lexus              es 350 sedan 4d
#
#         condition    cylinders fuel  odometer title_status transmission drive  \
# ...

# %% [markdown]
# #Task 1.4
# # need to drop this column as id is not a measurable column
# UsedVehicle.drop(UsedVehicle[['id','url','image_url']].columns,axis=1,inplace = True)

# %%
#Task 2.7
usedVehicle2.describe()
# Out:
#               price           year      odometer            lat           long
# count  1.298830e+05  129883.000000  1.298830e+05  129883.000000  129883.000000
# mean   8.460142e+04    2008.978881  1.138283e+05      38.468165     -92.228412
# std    1.499706e+07      10.419513  2.247545e+05       5.528921      17.417677
# min    0.000000e+00    1900.000000  0.000000e+00     -84.122245    -159.719900
# 25%    5.500000e+03    2006.000000  5.700000e+04      35.031300    -104.654790
# 50%    1.090000e+04    2011.000000  1.039730e+05      39.384750     -86.236592
# 75%    2.250000e+04    2015.000000  1.490000e+05      42.249000     -79.949997
# max    3.736929e+09    2022.000000  1.000000e+07      82.252826     173.885502

# %%
##Task 2.8

usedVehicle2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129883 entries, 31 to 426878
# Data columns (total 18 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   region        129883 non-null  object
#  1   price         129883 non-null  int64
#  2   year          129883 non-null  float64
#  3   manufacturer  129883 non-null  object
#  4   model         129883 non-null  object
#  5   condition     129883 non-null  object
#  6   cylinders     129883 non-null  object
#  7   fuel          129883 non-null  object
#  8   odometer      129883 non-null  float64
#  9   title_status  129883 non-null  object
#  10  transmission  129883 non-null  object
#  11  drive         129883 non-null  object
#  12  type          129883 non-null  object
#  13  paint_color   129883 non-null  object
#  14  state         129883 non-null  object
#  15  lat           129883 non-null  float64
#  16  long          129883 non-null  float64
# ...

# %%
#3.0
# validating if i need to reformat data
#rerunn
usedVehicle2['posting_date'].unique()
# Out:
# array(['2021-05-03T14:02:03-0500', '2021-05-03T13:41:25-0500',
#        '2021-05-03T12:41:33-0500', ..., '2021-04-04T17:00:48-0600',
#        '2021-04-04T03:21:34-0600', '2021-04-04T03:21:11-0600'],
#       dtype=object)

# %%
#3.0.1

usedVehicle2['posting_date'].head()
# Out:
# 31    2021-05-03T14:02:03-0500
# 32    2021-05-03T13:41:25-0500
# 33    2021-05-03T12:41:33-0500
# 34    2021-05-03T12:12:59-0500
# 35    2021-05-03T11:31:14-0500
# Name: posting_date, dtype: object

# %%
#3.0.2
usedVehicle2['posting_date']
# Out:
# 31        2021-05-03T14:02:03-0500
# 32        2021-05-03T13:41:25-0500
# 33        2021-05-03T12:41:33-0500
# 34        2021-05-03T12:12:59-0500
# 35        2021-05-03T11:31:14-0500
#                     ...
# 426863    2021-04-05T02:50:20-0600
# 426866    2021-04-05T02:41:26-0600
# 426868    2021-04-04T17:00:48-0600
# 426874    2021-04-04T03:21:34-0600
# 426878    2021-04-04T03:21:11-0600
# Name: posting_date, Length: 129883, dtype: object

# %%
#3.0.3
#create new column after stripping out timezone.  
#I dont think this will make much of an issue if there were no timezone to datat
usedVehicle2['posting_date2']=usedVehicle2['posting_date'].str[:10]

# %%
#3.0.4
usedVehicle2['posting_date2']=pd.to_datetime(usedVehicle2['posting_date2'])

# %%
#3.0.5
usedVehicle2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129883 entries, 31 to 426878
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   region         129883 non-null  object
#  1   price          129883 non-null  int64
#  2   year           129883 non-null  float64
#  3   manufacturer   129883 non-null  object
#  4   model          129883 non-null  object
#  5   condition      129883 non-null  object
#  6   cylinders      129883 non-null  object
#  7   fuel           129883 non-null  object
#  8   odometer       129883 non-null  float64
#  9   title_status   129883 non-null  object
#  10  transmission   129883 non-null  object
#  11  drive          129883 non-null  object
#  12  type           129883 non-null  object
#  13  paint_color    129883 non-null  object
#  14  state          129883 non-null  object
#  15  lat            129883 non-null  float64
#  16  long           129883 non-null  float64
# ...

# %%
#3.0.6
type(usedVehicle2['posting_date2'])
# Out:
# pandas.core.series.Series

# %%
usedVehicle2
# Out:
#          region  price    year manufacturer                        model  \
# 31       auburn  15000  2013.0         ford                    f-150 xlt
# 32       auburn  27990  2012.0          gmc  sierra 2500 hd extended cab
# 33       auburn  34590  2016.0    chevrolet        silverado 1500 double
# 34       auburn  35000  2019.0       toyota                       tacoma
# 35       auburn  29990  2016.0    chevrolet        colorado extended cab
# ...         ...    ...     ...          ...                          ...
# 426863  wyoming  25590  2017.0      unknown     Genesis G80 3.8 Sedan 4D
# 426866  wyoming  32990  2016.0     infiniti        qx80 sport utility 4d
# 426868  wyoming      0  2010.0       toyota                        venza
# 426874  wyoming  33590  2018.0        lexus              gs 350 sedan 4d
# 426878  wyoming  28990  2018.0        lexus              es 350 sedan 4d
#
#         condition    cylinders fuel  odometer title_status transmission drive  \
# ...

# %%
#Task 4.0
usedVehicle2[['model','fuel','transmission']]
# Out:
#                               model fuel transmission
# 31                        f-150 xlt  gas    automatic
# 32      sierra 2500 hd extended cab  gas        other
# 33            silverado 1500 double  gas        other
# 34                           tacoma  gas    automatic
# 35            colorado extended cab  gas        other
# ...                             ...  ...          ...
# 426863     Genesis G80 3.8 Sedan 4D  gas    automatic
# 426866        qx80 sport utility 4d  gas    automatic
# 426868                        venza  gas    automatic
# 426874              gs 350 sedan 4d  gas    automatic
# 426878              es 350 sedan 4d  gas        other
#
# [129883 rows x 3 columns]

# %%
#Task 4.1
usedVehicle2['transmission'].unique()
# Out:
# array(['automatic', 'other', 'manual', 'unknown'], dtype=object)

# %%
#Task 4.2
usedVehicle2['fuel'].unique()
# Out:
# array(['gas', 'diesel', 'other', 'hybrid', 'electric'], dtype=object)

# %%
#Task 4.3
usedVehicle2['model'].unique()
# Out:
# array(['f-150 xlt', 'sierra 2500 hd extended cab',
#        'silverado 1500 double', ..., 'rx& gls sport', 'gand wagoneer',
#        'Paige Glenbrook Touring'], dtype=object)

# %%
#Task 4.4
#getting rid of last 2 NaN
usedVehicle2.fillna({'fuel':'unknown','transmission':'unknown'
              },inplace = True)

# %%
usedVehicle2[['year','model','title_status','drive','type']]
# Out:
#           year                        model title_status drive     type
# 31      2013.0                    f-150 xlt        clean   rwd    truck
# 32      2012.0  sierra 2500 hd extended cab        clean   4wd   pickup
# 33      2016.0        silverado 1500 double        clean   4wd   pickup
# 34      2019.0                       tacoma        clean   4wd    truck
# 35      2016.0        colorado extended cab        clean   4wd   pickup
# ...        ...                          ...          ...   ...      ...
# 426863  2017.0     Genesis G80 3.8 Sedan 4D        clean   rwd    sedan
# 426866  2016.0        qx80 sport utility 4d        clean   rwd    other
# 426868  2010.0                        venza        clean   4wd  unknown
# 426874  2018.0              gs 350 sedan 4d        clean   rwd    sedan
# 426878  2018.0              es 350 sedan 4d        clean   fwd    sedan
#
# [129883 rows x 5 columns]

# %%
ddd=usedVehicle2.isna().sum()
ddd.sort_values(ascending = False)
# Out:
# region           0
# transmission     0
# posting_date     0
# long             0
# lat              0
# state            0
# paint_color      0
# type             0
# drive            0
# title_status     0
# price            0
# odometer         0
# fuel             0
# cylinders        0
# condition        0
# model            0
# manufacturer     0
# year             0
# posting_date2    0
# dtype: int64

# %%
#Task 5
# Export Data for EDA
usedVehicle2.to_csv(r'.\Data\UsedCarData\clean_vehicles2.csv',index = 0)
